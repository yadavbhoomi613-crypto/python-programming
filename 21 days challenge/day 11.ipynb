# %% [markdown]
# # DAY 11.... 21 DAYS CHALLENGE--- 5 QUESTIONS EVERYDAY

# %% [markdown]
# # QUESTION 1:

# %%
s=input("enter a  string:")
print("uppercase:", s.upper)
print("count of a :", s.count("a"))
print("startswith 'p':", s.startswith("p"))

# %% [markdown]
# # QUESTION 2:

# %%
nums=[5,87,9,23]
nums.append(2)
nums.sort()
nums.reverse()
print(nums)

# %% [markdown]
# # QUESTIO 3:

# %%
marks={"Bhoomi":10, "Anushka":10, "Sneha":10}
print("keys:",marks.keys())
print("values:",marks.values())
print("Bhoomi's marks:", marks["Bhoomi"])

# %% [markdown]
# # QUESTION 4:

# %%
text=input("enter a string:")
counnt=0
for ch in text:
    if ch in "aeiou":
        count+=1
print("vowels:", count)

# %% [markdown]
# # QUESTION 5:

# %%
s=input("enter a sentence:")
words=s.split()
count=0
for word in words:
    count+=1
print("number of words:", count)
