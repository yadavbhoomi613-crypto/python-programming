# %% [markdown]
# # DAY 10... 21 DAYS CHALLENGE--- 5 QUESTIONS EVERYDAY

# %% [markdown]
# # QUESTION 1:

# %%
nums=[1,5,7,65,23]
count=0
for n in nums:
    if n%2!=0:
        count+=1
        print("odd numbers are:",count)

# %% [markdown]
# # QUESTION 2:

# %%
subjs={"english":20, "maths":40, "psychology":60}
for value in subjs.values():
    print(value)

# %% [markdown]
# # QUESTION 3:

# %%
nums=[1,6,7,9]
product=1
for n in nums:
    product*=n
    print("product of the nums are:", product)

# %% [markdown]
# # QUESTION 4:

# %%
details={"name":"Bhoomi", "SGPA":7.48}
if age in details:
    print("key exists")
else:
    print("key doesn't exist")

# %% [markdown]
# # QUESTION 5:

# %%
nums=[3,5,7,9]
for n in nums:
    print(n, "square is:", n*n)
