# %% [markdown]
# # DAY 10... 21 DAYS CHALLENGE--- 5 QUESTIONS EVERYDAY

# %% [markdown]
# # QUESTION 1:

# %%
nums=[1,5,7,65,23]
count=0
for n in nums:
    if n%2!=0:
        count+=1
        print("odd numbers are:",count)
# Out:
# odd numbers are: 1
# odd numbers are: 2
# odd numbers are: 3
# odd numbers are: 4
# odd numbers are: 5

# %% [markdown]
# # QUESTION 2:

# %%
subjs={"english":20, "maths":40, "psychology":60}
for value in subjs.values():
    print(value)
# Out:
# 20
# 40
# 60

# %% [markdown]
# # QUESTION 3:

# %%
nums=[1,6,7,9]
product=1
for n in nums:
    product*=n
    print("product of the nums are:", product)
# Out:
# product of the nums are: 1
# product of the nums are: 6
# product of the nums are: 42
# product of the nums are: 378

# %% [markdown]
# # QUESTION 4:

# %%
student = {"name": "Bhoomi", "SGPA": 7.48}

if "age" in student:
    print("Key exists")
else:
    print("Key does not exist")
# Out:
# Key does not exist

# %% [markdown]
# # QUESTION 5:

# %%
nums=[3,5,7,9]
for n in nums:
    print(n, "square is:", n*n)
