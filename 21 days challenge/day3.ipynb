# %% [markdown]
# ## DAY3....21 DAYS HARD CHALLENGE------  5 QUESTIONS EVERYDAY

# %% [markdown]
# # QUESTION 1:
#
# STARTSWITH()

# %%
a="this is python"
print (a.startswith("th"))
# Out:
# True

# %%
a="this is python"
print (a.startswith("tp"))
# Out:
# False

# %% [markdown]
# # QUESTION 2:
#
# ENDSWITH

# %%
b="Bhoomi Yadav"
print(b.endswith("yadav"))
# Out:
# False

# %%
b="Bhoomi Yadav"
print(b.endswith("Yadav"))
# Out:
# True

# %% [markdown]
# # QUESTION 3:
#
# COUNT

# %%
c=[1,[2,7]]
print(c.count(3))
# Out:
# 0

# %%
c="plagiarism"
print(c.count("a"))
# Out:
# 2

# %%
c="plagiarism"
print(c.count("i"))
# Out:
# 2

# %% [markdown]
# # QUESTION 4:
#
# INDEX

# %%
d=(1,2,3,4,5)
print(d.index(3))
# Out:
# 2

# %%
d=(1,(2,3),4,5)
print(d.index(4))
# Out:
# 2

# %% [markdown]
# # QUESTION 5:
#
# RINDEX

# %%
e="python programming"
print(e.rindex("p"))
# Out:
# 7

# %%
e="python programming"
print(e.rindex("py"))
# Out:
# 0

# %%
e="python programming"
print(e.rindex("pr"))
# Out:
# 7

# %%
e="python programming"
print(len(e))
print(e.count)
print(e.rindex("p"))
# Out:
# 18
# <built-in method count of str object at 0x00000189CA714CF0>
# 7
