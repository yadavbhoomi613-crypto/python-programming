# %% [markdown]
# # DAY 4..... 21 DAYS CHALLENGE---- 5 QUESTIONS EVERY DAY
#
# # FIND

# %%
a="this is a sentence"
print(a.find("sentence"))
# Out:
# 10

# %% [markdown]
# # RFIND

# %%
a="I am 19 years old"
print(a.rfind("a"))
# Out:
# 10

# %% [markdown]
# # STRIP

# %%
a=" strip this line "
print(len(a))
print(len(a.strip()))
# Out:
# 17
# 15

# %% [markdown]
# # RSTRIP

# %%
s = "Welcome to Python   "

print(s.rstrip())
# Out:
# Welcome to Python

# %% [markdown]
# # LSTRIP

# %%
a="  welcome Batcch 25-26"
print((len(a.lstrip())))
# Out:
# 20
