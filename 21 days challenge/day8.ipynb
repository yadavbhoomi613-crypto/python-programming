# %% [markdown]
# # DAY 8.... 21 DAYS CHALLENGE--- 5 QUESTIONS EVERYDAY

# %% [markdown]
# # QUESTION 1:

# %%
lst = [10, 20, 30, 40]

for item in lst:
    print(item)

# %% [markdown]
# # QUESTION 2:

# %%
l=[2,4,6,8]
total=0
for num in l:
    total+=num
    print("sum=", total)

# %% [markdown]
# # QUESTION 3:

# %%
stu={"name": "John", "marks": 85}
stu["age"] = 20
print(stu)

# %% [markdown]
# # QUESTION 4:

# %%
data={"one":1, "two":2, "three":3}
for key,value in data.items():
    print(key, ":", value)

# %% [markdown]
# # QUESTION 5:

# %%
nums=[1,2,3,4,5,6,7,8,9,0]
count=0
for n in nums:
    if n%2==0:
        count+=1
print("even numbers count=", count)
