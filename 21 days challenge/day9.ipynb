# %% [markdown]
# # DAY 9.... 21 DAYS CHALLENGE--- 5 QUESTIONS EVERYDAY

# %% [markdown]
# # QUESTION1:

# %%
nums=[12,45,87,96,3]
largest=nums[0]
for n in nums:
    if n>largest:
        largest=n
        print("largest is:", largest)
# Out:
# largest is: 45
# largest is: 87
# largest is: 96

# %% [markdown]
# # QUESTION 2:

# %%
l=[1,5,3,4]
rev=[]
for i in range(len(l)-1,-1,-1):
    rev.append(l[i])
    print(rev)
# Out:
# [4]
# [4, 3]
# [4, 3, 5]
# [4, 3, 5, 1]

# %% [markdown]
# # QUESTION 3:

# %%
data={"a":1, "b":2, "c":3}
count=0
for kery in data:
    count+=1
    print("total keys=", count)
# Out:
# total keys= 1
# total keys= 2
# total keys= 3

# %% [markdown]
# # QUESTION 4:

# %%
nums=[21,54,98,623,56]
for n in nums:
    if n%2==0:
        print("even nums are:", n)
# Out:
# even nums are: 54
# even nums are: 98
# even nums are: 56

# %% [markdown]
# # QUESTION 5:

# %%
keys=["appple", "potato", "pepper"]
values=["fruits", "vegegie", "spice"]
dict={}
for i in range(len(keys)):
    dict[keys[i]]=values[i]
    print(dict)
# Out:
# {'appple': 'fruits'}
# {'appple': 'fruits', 'potato': 'vegegie'}
# {'appple': 'fruits', 'potato': 'vegegie', 'pepper': 'spice'}
