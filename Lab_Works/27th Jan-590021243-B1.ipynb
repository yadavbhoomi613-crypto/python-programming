# %% [markdown]
# # Write a program to print all the digits of a 6 dig numvber, no digit is 0

# %%
a=135792
r=a
while r>0:
    print_value=r
    print(print_value)
    r=a//10
    a=r
# Out:
# 135792
# 13579
# 1357
# 135
# 13
# 1
