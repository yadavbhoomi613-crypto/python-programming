# %% [markdown]
# # Experiment 6: Lists, tuples, dictionary

# %% [markdown]
# ### 1. Scan n values in range 0-3 and print the number of times each value has occurred.

# %%
n = int(input("Enter number of values: "))

count = [0, 0, 0, 0] 

print("Enter values (between 0 and 3):")
for i in range(n):
    num = int(input())
    if 0 <= num <= 3:
        count[num] += 1
    else:
        print("Invalid input! Please enter value between 0 and 3.")

for i in range(4):
    print(f"{i} occurred {count[i]} times")
# Out:
# Enter values (between 0 and 3):
# Invalid input! Please enter value between 0 and 3.
# 0 occurred 0 times
# 1 occurred 1 times
# 2 occurred 2 times
# 3 occurred 1 times

# %% [markdown]
# ### 2. Create a tuple to store n numeric values and find the average of all values.

# %%
n = int(input("Enter number of values: "))

values = []

print("Enter the numbers:")
for i in range(n):
    num = float(input())
    values.append(num)

numbers = tuple(values) 

average = sum(numbers) / len(numbers)

print("Tuple:", numbers)
print("Average:", average)
# Out:
# Enter the numbers:
# Tuple: (23.0, 12.0, 54.0, 26.0)
# Average: 28.75

# %% [markdown]
# ### 3. WAP to input a list of scores for N students in a list data type. Find the score of
# ### the runner-up and print the output.
# ### Sample Input
# ### N = 5
# ### Scores= 2 3 6 6 5
# ### Sample output
# ### 5
# ### Note: Given list is [2, 3, 6, 6, 5]. The maximum score is 6, second maximum is
# ### 5. Hence, we print 5 as the runner-up score

# %%
N = int(input("Enter number of students: "))

scores = list(map(int, input("Enter the scores separated by space: ").split()))

unique_scores = list(set(scores))

unique_scores.remove(max(unique_scores))

runner_up = max(unique_scores)

print("Runner-up score:", runner_up)
# Out:
# Runner-up score: 5

# %% [markdown]
# ### 4.. Create a dictionary of n persons where key is name and value is city.
# ### a. Display all names
# ### b. Display all city names
# ### c. Display student names and cities of all students.
# ### d. Count the number of students in each city.

# %%
n = int(input("Enter number of persons: "))

students = {}

for i in range(n):
    name = input("Enter name: ")
    city = input("Enter city: ")
    students[name] = city
print("\nNames:")
for name in students.keys():
    print(name)

print("\nCities:")
for city in students.values():
    print(city)

print("\nStudent Details:")
for name, city in students.items():
    print(name, "->", city)

city_count = {}

for city in students.values():
    if city in city_count:
        city_count[city] += 1
    else:
        city_count[city] = 1

print("\nNumber of students in each city:")
for city, count in city_count.items():
    print(city, ":", count)
# Out:
# Names:
# Ekansh
# Mohit
# Krish
# Aryan
# Archit
#
# Cities:
# Dehradun
# Haridwar
# Patna
# Dehradun
# Vikasnagar
#
# Student Details:
# Ekansh -> Dehradun
# Mohit -> Haridwar
# Krish -> Patna
# Aryan -> Dehradun
# Archit -> Vikasnagar
#
# Number of students in each city:
# Dehradun : 2
# Haridwar : 1
# Patna : 1
# Vikasnagar : 1

# %% [markdown]
# ### 5. Store details of n movies in a dictionary by taking input from the user. Each
# ### movie must store details like name, year, director name, production cost,
# ### collection made (earning) & perform the following :-
# ### a. print all movie details
# ### b. display name of movies released before 2015
# ### c. print movies that made a profit.
# ### d. print movies directed by a particular director.

# %%
n = int(input("Enter number of movies: "))

movies = {}

for i in range(n):
    print(f"\nEnter details for movie {i+1}")
    
    name = input("Movie name: ")
    year = int(input("Year of release: "))
    director = input("Director name: ")
    cost = float(input("Production cost: "))
    collection = float(input("Collection made: "))
    
    movies[name] = {
        "year": year,
        "director": director,
        "cost": cost,
        "collection": collection
    }

print("\nAll Movie Details:")
for name, details in movies.items():
    print(name, "->", details)

print("\nMovies released before 2015:")
for name, details in movies.items():
    if details["year"] < 2015:
        print(name)

print("\nMovies that made profit:")
for name, details in movies.items():
    if details["collection"] > details["cost"]:
        print(name)

search_director = input("\nEnter director name to search: ")

print(f"\nMovies directed by {search_director}:")
for name, details in movies.items():
    if details["director"].lower() == search_director.lower():
        print(name)
# Out:
# Enter details for movie 1
#
# Enter details for movie 2
#
# All Movie Details:
# RRR -> {'year': 2019, 'director': 'Rajamoli', 'cost': 600.0, 'collection': 2000.0}
# Dj -> {'year': 2014, 'director': 'Mohit', 'cost': 200.0, 'collection': 500.0}
#
# Movies released before 2015:
# Dj
#
# Movies that made profit:
# RRR
# Dj
#
# Movies directed by mohit:
# Dj
